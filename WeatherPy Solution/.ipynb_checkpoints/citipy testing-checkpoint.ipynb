# %%
import random
import numpy as np
from citipy import citipy
import openweathermapy.core as ow
import pandas as pd
import matplotlib.pyplot as plt
import requests

#openweathermap api key
ow_api = "25bc90a1196e6f153eece0bc0b0fc9eb"
#ow settings
settings = {"units": "imperial", "appid": ow_api}

# %%
#owm for new brunswick
data_nb = ow.find_city("New Brunswick", **settings)
data_nb
# Out:
# [{'clouds': {'all': 75},
#   'coord': {'lat': 40.4862, 'lon': -74.4519},
#   'dt': 1529600100,
#   'id': 5101717,
#   'main': {'humidity': 61,
#    'pressure': 1006,
#    'temp': 76.46,
#    'temp_max': 78.8,
#    'temp_min': 71.6},
#   'name': 'New Brunswick',
#   'rain': None,
#   'snow': None,
#   'sys': {'country': 'US'},
#   'weather': [{'description': 'broken clouds',
#     'icon': '04d',
#     'id': 803,
#     'main': 'Clouds'}],
#   'wind': {'deg': 38, 'speed': 6.96}},
#  {'clouds': {'all': 90},
#   'coord': {'lat': 39.9442, 'lon': -86.5228},
#   'dt': 1529599080,
#   'id': 4918273,
#   'main': {'humidity': 100,
#    'pressure': 1009,
#    'temp': 71.19,
#    'temp_max': 71.6,
#    'temp_min': 69.8},
#   'name': 'New Brunswick',
#   'rain': None,
#   'snow': None,
#   'sys': {'country': 'US'},
#   'weather': [{'description': 'heavy intensity rain',
#     'icon': '10d',
#     'id': 502,
#     'main': 'Rain'},
#    {'description': 'mist', 'icon': '50d', 'id': 701, 'main': 'Mist'}],
#   'wind': {'deg': 200, 'speed': 4.7}},
#  {'clouds': {'all': 90},
#   'coord': {'lat': 39.2059, 'lon': -87.1215},
#   'dt': 1529599380,
#   'id': 4260453,
#   'main': {'humidity': 78,
#    'pressure': 1007,
#    'temp': 76.05,
#    'temp_max': 77,
#    'temp_min': 73.4},
#   'name': 'New Brunswick',
#   'rain': None,
#   'snow': None,
#   'sys': {'country': 'US'},
#   'weather': [{'description': 'overcast clouds',
#     'icon': '04d',
#     'id': 804,
#     'main': 'Clouds'}],
#   'wind': {'deg': 190, 'speed': 5.82}}]

# %%
data_nb2 = ow.get_current("New Brunswick", **settings)
data_nb2
# Out:
# {'base': 'stations',
#  'clouds': {'all': 1},
#  'cod': 200,
#  'coord': {'lat': 40.49, 'lon': -74.45},
#  'dt': 1529603760,
#  'id': 5101717,
#  'main': {'humidity': 42,
#   'pressure': 1008,
#   'temp': 80.6,
#   'temp_max': 82.4,
#   'temp_min': 77},
#  'name': 'New Brunswick',
#  'sys': {'country': 'US',
#   'id': 1977,
#   'message': 0.0054,
#   'sunrise': 1529573262,
#   'sunset': 1529627513,
#   'type': 1},
#  'visibility': 16093,
#  'weather': [{'description': 'clear sky',
#    'icon': '01d',
#    'id': 800,
#    'main': 'Clear'}],
#  'wind': {'deg': 20, 'speed': 5.82}}

# %%
data_nb2['weather'][0]['description']
# Out:
# 'clear sky'

# %%
# lathome = data_nb['coord']['lat']
# lnghome = data_nb['coord']['lon']

# latlng = [lathome, lnghome]
# latlng

# %%
#return on citipy
city = citipy.nearest_city(40.49, -74.45)
name = city.city_name
country = city.country_code

print(f"I live in {name}, {country}")
# Out:
# I live in new brunswick, us

# %%
#create a dataframe with a list of 100 random cities
# randlat = random.uniform(-90, 90)
# randlong = random.uniform(-180, 180)
# city = citipy.nearest_city(randlat, randlong)
# cityname = city.city_name
# citycountry = city.country_code

citynames = []
citycountries = []

for i in range(1300):
    randlat = random.uniform(-90, 90)
    randlong = random.uniform(-180, 180)
    city = citipy.nearest_city(randlat, randlong)
    citynames.append(city.city_name)
    citycountries.append(city.country_code)
    
df = pd.DataFrame({'city': citynames,
                  'country': citycountries})

df.count()
# Out:
# city       1300
# country    1300
# dtype: int64

# %%
df = df.drop_duplicates(keep="first")
yope = df['city'].count().sum()
print(f"there are {yope} entries")
# Out:
# there are 535 entries

# %%
#add this stuff to the df
df.set_index(['city', 'country'])
df['latitude'] = ''
df['longitude'] = ''
df['temperature'] = ''
df['humidity'] = ''
df['cloudiness'] = ''
df['wind speed'] = ''
df['city'] = df['city'].str.title()
df['country'] = df['country'].str.upper()
df.head()
# Out:
#         city country latitude longitude temperature humidity cloudiness  \
# 0  Mangaldai      IN
# 1    Sorland      NO
# 2   Luderitz      NA
# 3    Mataura      PF
# 4      Pevek      RU
#
#   wind speed
# 0
# 1
# 2
# 3
# 4

# %%
#this takes the first element under city and the first element under country then returns its data using openweathermaps
hey = df['city'][0] + ',' + df['country'][0]
data = ow.find_city(hey, **settings)
data

#then we can add that data to the dataframe
# df['temperature'][0] = data[0]['main']['temp']
# df.head()
# Out:
# []

# %%
counter = 0

for index, row in df.iterrows():
#     print(index, row['city'], row['country'])
#     #create string for data
    cityloc = row['city']
    data = ow.find_city(cityloc, **settings)
#     city = row['city']
#     country = row['country']
#     url = "https://api.openweathermap.org/data/2.5/weather?"
#     queryurl = f"{url}appid={ow_api}&units=Imperial&q={city},{country}"
# #     print("now retrieving city # " + str(counter))
# #     print(queryurl)
# #     counter += 1
    
#     data = requests.get(queryurl).json()

    try:
        row['temperature'] = data[0]['main']['temp']
        row['humidity'] = data[0]['main']['humidity']
        row['cloudiness'] = data[0]['clouds']['all']
        row['wind speed'] = data[0]['wind']['speed']
        row['latitude'] = data[0]['coord']['lat']
        row['longitude'] = data[0]['coord']['lon']
    except:
        row['latitude'] = np.NaN
        print(f"Missing data for {row['city']}, {row['country']}... skipping...")
    
df.head()
# Out:
# Missing data for taolanaro, mg... skipping...
# Missing data for lolua, tv... skipping...
# Missing data for grand river south east, mu... skipping...
# Missing data for barentsburg, sj... skipping...
# Missing data for nizhneyansk, ru... skipping...
# Missing data for bengkulu, id... skipping...
# Missing data for wulanhaote, cn... skipping...
# Missing data for tunduru, tz... skipping...
# Missing data for saleaula, ws... skipping...
# Missing data for illoqqortoormiut, gl... skipping...
# Missing data for mys shmidta, ru... skipping...
# Missing data for chagda, ru... skipping...
# Missing data for amderma, ru... skipping...
# Missing data for halalo, wf... skipping...
# Missing data for tawkar, sd... skipping...
# Missing data for tumannyy, ru... skipping...
# Missing data for dolbeau, ca... skipping...
# Missing data for rungata, ki... skipping...
# Missing data for belushya guba, ru... skipping...
# Missing data for inderborskiy, kz... skipping...
# Missing data for samusu, ws... skipping...
# Missing data for candawaga, ph... skipping...
# Missing data for zhanatas, kz... skipping...
# Missing data for tsihombe, mg... skipping...
# Missing data for sentyabrskiy, ru... skipping...
# Missing data for manzil tamim, tn... skipping...
# Missing data for acuna, mx... skipping...
# Missing data for qafsah, tn... skipping...
#         city country latitude longitude temperature humidity cloudiness  \
# 0  taolanaro      mg      NaN
# 1  sept-iles      ca  50.2001  -66.3821          59       38         40
# 2      adrar      dz  27.8734   -0.2875       109.4       13          0
# 3     xiamen      cn  24.4587   118.075        82.4       88         40
# 4  esperance      au  10.2447  -61.4506        82.4       83         40
#
#   wind speed
# 0
# 1      13.87
# 2      16.11
# 3       2.24
# 4      11.41

# %%
df = df.dropna(axis=0, how="any")
df
# df.isnull()
# Out:
#                  city country latitude longitude temperature humidity  \
# 1           sept-iles      ca  50.2001  -66.3821          59       38
# 2               adrar      dz  27.8734   -0.2875       109.4       13
# 3              xiamen      cn  24.4587   118.075        82.4       88
# 4           esperance      au  10.2447  -61.4506        82.4       83
# 5             rikitea      pf -23.1203  -134.969       72.98      100
# 7             ushuaia      ar  -54.807  -68.3074        30.2       86
# 8            klaksvik      fo  62.2266   -6.5891        51.8       62
# 10          upernavik      gl  72.7868  -56.1549       33.74       93
# 12             kodiak      us  39.9519  -94.7572        64.4       93
# 15               olga      ru  34.1125  -118.166       65.16       88
# 16             hobart      au -42.8826   147.328          41       80
# 17        chillicothe      us  39.3331  -82.9825       71.62       88
# 18         chokurdakh      ru  70.6192   147.902       42.29       82
# 21           luderitz      na -26.6481   15.1594       63.26       68
# 23             dikson      ru  73.5069   80.5464       35.99       84
# 26          abbeville      us  50.1061    1.8337        62.6       48
# 27              kapaa      us  22.0752  -159.319       74.07       83
# 28          kununurra      au -15.7731   128.739        55.4       58
# 29           victoria      sc   5.2785   115.242        75.2      100
# 31         bredasdorp      za -34.5331   20.0428        69.8       28
# 32             atuona      pf     -9.8  -139.033       81.08       99
# 33          jamestown      sh -33.2075   138.603       24.38       63
# 34         big spring      us  32.2504  -101.479       84.45       58
# 35              jumla      np  29.2754   82.1825       37.52       95
# 38          busselton      au -33.6445   115.349       58.31      100
# 40         baijiantan      cn  45.6333   85.1833       79.64       33
# 41        yellowknife      ca  62.4541  -114.377          68       52
# 42               lebu      cl   8.9611   38.7254       68.48       37
# 43            horadiz      az  39.4511   47.3315       85.67       37
# 44   diego de almagro      cl -26.3911   -70.046       62.99       79
# ..                ...     ...      ...       ...         ...      ...
# 538          iracoubo      gf   5.4794  -53.2058       81.44       85
# 539  praia da vitoria      pt  38.7333  -27.0667        73.4       64
# 541         katherine      au -14.4657   132.263        57.2       50
# 544       finschhafen      pg  -6.6041   147.854       70.28      100
# 545       kangaatsiaq      gl  68.3065  -53.4641       36.08       96
# 546            pinyug      ru  60.2505   47.7857       57.23       80
# 547           salalah      om  17.0149   54.0957        82.4       83
# 548               reo      bf  12.3187   -2.4697      102.32       32
# 549          sisimiut      gl  66.9395  -53.6735       36.98       94
# 550            kawalu      id  -7.3817   108.208       67.85       97
# 554            nemuro      jp  43.3236   145.575       52.64       96
# 555           newport      us  51.5882   -2.9975        65.3       39
# 558            usinsk      ru  65.9957   57.5571       62.18       69
# 560            fallon      us  46.8369  -105.123        69.8       68
# 565            ca mau      vn   9.1792   105.146       80.09       96
# 569         otradnoye      ru  59.7727    30.802        60.8       87
# 571         bundaberg      au -24.8654   152.352       64.34      100
# 572        porto novo      cv -23.6775  -45.4418        73.4       60
# 577            gornyy      ru  51.7561   48.5385       78.92       27
# 578          hamilton      bm  32.2956  -64.7828        82.4       69
# 579           calbuco      cl -41.7713  -73.1276        44.6      100
# 580     san cristobal      ec  -0.3855  -78.5488        51.8       71
# 582      villaviciosa      es  43.4813   -5.4335        64.4      100
# 586           dunedin      nz  -45.874   170.504       22.76       80
# 587         eganville      ca  45.5407  -77.1005        57.2       50
# 589         khingansk      ru  49.1167   131.183       52.28       83
# 592      ponta do sol      cv -20.6335  -45.9989       74.96       61
# 596             homer      us  59.6441   -151.54       50.76       81
# 597         mporokoso      zm  -9.3705   30.1194       80.36       26
# 598             rocha      uy -34.4811  -54.3366       58.22       76
#
#     cloudiness wind speed
# 1           40      13.87
# 2            0      16.11
# 3           40       2.24
# 4           40      11.41
# 5           56        7.4
# 7           90       26.4
# 8            0      14.99
# 10         100       5.39
# 12          90      13.87
# 15          90        4.7
# 16          40       9.17
# 17          90       8.05
# 18           0       4.38
# 21           0      16.02
# 23           0      19.48
# 26           0      12.75
# 27          20       7.29
# 28           0      10.65
# 29          75       2.24
# 31           0      16.11
# 32          56         14
# 33           0       2.93
# 34           1       3.36
# 35          24       2.71
# 38          48       4.94
# 40          92       5.39
# 41          75       9.17
# 42          92       1.14
# 43           0       4.94
# 44           0       1.25
# ..         ...        ...
# 538         48       3.71
# 539         20       7.52
# 541          0       8.05
# 544         92       2.15
# 545         44      12.77
# 546         92      12.55
# 547         40       9.17
# 548         44       3.15
# 549         56       1.14
# 550         80       1.03
# 554         88      14.12
# 555          0      10.29
# 558         48      11.65
# 560          1        4.7
# 565          0       5.17
# 569         90       6.71
# 571         24      15.57
# 572          0       2.24
# 577          0      18.03
# 578         20       20.8
# 579         90       6.93
# 580         75      10.29
# 582         75       5.82
# 586          0       4.94
# 587          1       6.93
# 589          0       3.38
# 592          0       5.17
# 596         40       6.93
# 597         24       5.17
# 598          0      17.47
#
# [292 rows x 8 columns]

# %%
#latitude vs temperature
plt.scatter(df['latitude'], df['temperature'], marker="o")

plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

plt.show()

# %%
#latitude vs humidity
plt.scatter(df['latitude'], df['humidity'], marker="o")

plt.title("City Latitude vs. Humidity")
plt.ylabel("Temperature (F)")
plt.xlabel("Humidity")
plt.grid(True)

plt.show()

# %%
#latitude vs cloudiness
plt.scatter(df['latitude'], df['cloudiness'], marker="o")

plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Temperature (F)")
plt.xlabel("Cloudiness")
plt.grid(True)

plt.show()

# %%
#latitude vs wind speed
plt.scatter(df['latitude'], df['wind speed'], marker="o")

plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Temperature (F)")
plt.xlabel("Wind Speed")
plt.grid(True)

plt.show()
